# %%
#1.Print - Adds spaces when argument passed by separtion(,)
print("Hello","World")
# Out:
# Hello World

# %%
#Data types
'''
Python is dynamically typing language we don't need to declare
data type explicitly.It auto dtects while running program based on assignment.
'''
#Integer
i=10
print("Integer",i)
#float
f=10.4
print("Float",f)
#string
s="Hi"
print("String",s)
#boolean
b=True
print("Boolean",b)
#complex
c=4+6j
print("Complex:",c)
#Set:An unorderd collection of unique elements
sampleSet={1,2.3,"Kedar"}
print("Set :",sampleSet)
#Dictionary:Collection of key:pair values
dictionary={'Age':1,'Name':'Kedar'}
print("Dictionary :",dictionary)
#Tuple :  An immutable ordered collection 
tup=("Kedar",18) # tup = "Kedar",18 also can be tuple
print("Tuple:",tup)
#range: sequence of numbers
print("Range:",range(5))
#list:Mutable orderd collection of elemets with diff data types
l=[1,"k",True]
print("List:",l)
#None:absence of value
value=None
print(value)
'''Data types methods'''
# To get data type we use <type()>
print(type(l))
# To get unique identifier of an object we use <id()>
print(id(l))
#To check if a var matches a specific data type <isinstance()>
isinstance(1,int)
#Type casting : reprsenting the value of <data typex> by <data typey>
x=str(int(float(2.8)))
print(x)
# Out:
# Integer 10
# Float 10.4
# String Hi
# Boolean True
# Complex: (4+6j)
# Set : {1, 2.3, 'Kedar'}
# Dictionary : {'Age': 1, 'Name': 'Kedar'}
# Tuple: ('Kedar', 18)
# Range: range(0, 5)
# List: [1, 'k', True]
# None
# <class 'list'>
# 2131628715584
# 2

# %%
#---------------String------------------
str1='Hello' #single line
str2=''' Multi line'''#multi line
#Note you can use single or double quotes
# String concatenation(combininig multiple strings by '+' opereator)
print(str1+str2)
#string interpolation:process of inserting variables and expressions into a string is called string
print(f"{str1}")
#String as a arrays
print("1st char in str1 :",str1[0])
print("\'H\' exist in str2:", 'H' in str2)
print("-> Looping through string")
for x in str1:
    print(x)
print("-> Conditional & string ")
if "Hello" in str1:
    print("Yes")
if "Hi" not in str1:
    print("No\n")
print("Slicing : extract a specific portion of string \nSyntax : string[start:stop:step]")
'''A helpful trick you can do with the step parameter is to reverse a 
string by setting step to -1, and leaving start and stop blank:'''
my_str = 'Hello world'
print(my_str[::-1])
print("\n----------------------String Methods------------------------")
x="Kedar Jamadar"
y=["Kedar","Ganesh"]
print("1. length of x:",len(x))
print("2. x.upper():",x.upper())
print("3. x.lower():",x.lower())
print("""4. strip(): Returns a new string with the specified leading and 
trailing characters removed. If no argument is passed it removes leading and 
trailing whitespace.:\n""",x.strip())
print("""5. replace(old, new,no): Returns a new string with all
occurrences of old replaced by new. if no is not specified\n""",x.replace("K","R"))
print("""6. split(separator): Splits a string on a specified separator into
a list of strings.If no separator is specified, it splits on whitespace.\n""",x.split())
print("""7. join(iterable): Joins elements of an iterable into a string with a separator.\n""",','.join(y))
print("""8. startswith(prefix)/endswith(suffix): Returns a boolean indicating if a stringstarts /ends
with the specified prefix/suffix.\n""",x.startswith('K') and x.endswith('r'))
print("""9. count(substring): Returns the number of times a substring appears in a string.\n""",x.count('r'))
# Out:
# Hello Multi line
# Hello
# 1st char in str1 : H
# 'H' exist in str2: False
# -> Looping through string
# H
# e
# l
# l
# o
# -> Conditional & string
# Yes
# No
#
# Slicing : extract a specific portion of string
# Syntax : string[start:stop:step]
# dlrow olleH
#
# ----------------------String Methods------------------------
# 1. length of x: 13
# 2. x.upper(): KEDAR JAMADAR
# 3. x.lower(): kedar jamadar
# 4. strip(): Returns a new string with the specified leading and
# trailing characters removed. If no argument is passed it removes leading and
# trailing whitespace.:
#  Kedar Jamadar
# 5. replace(old, new,no): Returns a new string with all
# occurrences of old replaced by new. if no is not specified
#  Redar Jamadar
# 6. split(separator): Splits a string on a specified separator into
# a list of strings.If no separator is specified, it splits on whitespace.
#  ['Kedar', 'Jamadar']
# 7. join(iterable): Joins elements of an iterable into a string with a separator.
#  Kedar,Ganesh
# ...

# %%
# Build a Caesar cipher
"""This is one of the simplest techniques to encrypt text,which consists of 
substituting each letter of the plain text with the letter found at a fixed 
number of positions down the alphabet. For example, with a shift of 5,
a would be replaced by f, b by g and so on."""
def caesar(text,shift,encrypt=True):
    #shift=5
    if not isinstance(shift,int):
        return "Shift must be an integer value."
    if shift<1 or shift >25:
        return 'Shift must be an integer between 1 and 25.'
    alphabet="abcdefghijklmnopqrstuvwxyz"
    #text="hello world"
    if True:
        shift=-shift
    shifted_alphabet=alphabet[shift:] +alphabet[:shift]
    translation_table=str.maketrans(alphabet+alphabet.upper(),shifted_alphabet+shifted_alphabet.upper())
    #encrypted_text=text.translate(translation_table)
    return text.translate(translation_table)
def encrypt(text,shift):
    return caesar(text,shift)
def decrypt(text,shift):
    return caesar(text,shift,False)
encrypted_text="Pbhentr vf sbhaq va hayvxryl cynprf." #encrypt("freeCodeCamp",3)
decrypted_text=decrypt(encrypted_text,13)
print(decrypted_text)
# Out:
# Courage is found in unlikely places.
